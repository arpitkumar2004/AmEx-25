# %%
# prompt: adding the google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
def read_data(folder_path):
    files = [f for f in os.listdir(folder_path) if f.endswith('.parquet') or f.endswith('.csv')]
    dataframes = {}
    for file in files:
        file_path = os.path.join(folder_path, file)
        if file.endswith('.csv'):
            df = pd.read_csv(file_path)
        elif file.endswith('.parquet'):
            df = pd.read_parquet(file_path)
        dataframes[file] = df
    return dataframes

# %%
data_dictionary = pd.read_csv(r"/content/drive/MyDrive/AmEx/details/data_dictionary.csv")

# %%
df = pd.read_parquet(r"/content/drive/MyDrive/AmEx/data/train_data.parquet")

# %%
test_df = pd.read_parquet(r"/content/drive/MyDrive/AmEx/data/test_data.parquet")

# %%
missing_value_count = df.isnull().sum().sort_values( ascending=False)

# %%
# features which have more than 75% missing values
features_to_drop = missing_value_count[missing_value_count > 0.75 * len(df)].index.tolist()
print("Features with more than 75% missing values:", features_to_drop)
# Out:
# Features with more than 75% missing values: ['f136', 'f135', 'f112', 'f122', 'f80', 'f360', 'f120', 'f34', 'f19', 'f13', 'f21', 'f14', 'f17', 'f20', 'f15', 'f16', 'f18', 'f84', 'f37', 'f189', 'f221', 'f205', 'f154', 'f176', 'f64', 'f88', 'f66', 'f70', 'f92', 'f220', 'f33', 'f79', 'f36', 'f118', 'f114', 'f81', 'f117', 'f4', 'f121', 'f3', 'f119', 'f116', 'f218']

# %%
def print_feature_details(features_to_drop, data_dictionary):
    for feature in features_to_drop:
        feature_info = data_dictionary[data_dictionary['masked_column'] == feature]
        if not feature_info.empty:
            for _, row in feature_info.iterrows():
                print(f"ID: {row['masked_column']}\nDescription: {row['Description']}\nType: {row['Type']}\n{'-'*60}")
        else:
            print(f"ID: {feature} - No information available in data dictionary.\n{'-'*60}")

# %%
# Rearrange the features in ascending order of missing values in a new DataFrame
sorted_columns = missing_value_count.sort_values(ascending=True).index.tolist()
df_sorted = df[sorted_columns]
df_sorted.sample(10)
# Out:
#                                                   id1      id2      id3  \
# 711884   1890919_224505_16-23_2023-11-03 09:26:59.940  1890919   224505
# 310047    1818194_60448_16-23_2023-11-03 21:10:19.466  1818194    60448
# 692730  1707942_5420674_16-23_2023-11-01 13:34:19.402  1707942  5420674
# 470325   1456514_920103_16-23_2023-11-02 04:05:20.528  1456514   920103
# 757411  1209274_5420674_16-23_2023-11-01 09:46:09.536  1209274  5420674
# 119388    1739351_56483_16-23_2023-11-01 21:12:14.939  1739351    56483
# 133033   1700033_707815_16-23_2023-11-03 06:48:51.293  1700033   707815
# 661222    1248085_75531_16-23_2023-11-01 08:01:48.023  1248085    75531
# 343699     1052281_5718_16-23_2023-11-03 12:43:07.319  1052281     5718
# 757108    1106790_79016_16-23_2023-11-02 11:43:39.748  1106790    79016
#
#                             id4         id5  y   f350 f349 f307 f306  ...  \
# 711884  2023-11-03 09:26:59.940  2023-11-03  0  34018    6  0.0  0.0  ...
# 310047  2023-11-03 21:10:19.466  2023-11-03  0  76127    6  0.0  0.0  ...
# 692730  2023-11-01 13:34:19.402  2023-11-01  0  48848    4  0.0  0.0  ...
# 470325  2023-11-02 04:05:20.528  2023-11-02  0  14719    5  0.0  0.0  ...
# 757411  2023-11-01 09:46:09.536  2023-11-01  0  35155    4  0.0  0.0  ...
# 119388  2023-11-01 21:12:14.939  2023-11-01  0  76295    4  0.0  0.0  ...
# 133033  2023-11-03 06:48:51.293  2023-11-03  0  24510    6  0.0  0.0  ...
# 661222  2023-11-01 08:01:48.023  2023-11-01  0  28902    4  0.0  0.0  ...
# 343699  2023-11-03 12:43:07.319  2023-11-03  0  45778    6  0.0  0.0  ...
# 757108  2023-11-02 11:43:39.748  2023-11-02  0  42217    5  0.0  0.0  ...
#
#          f13   f19   f34  f120  f360   f80  f122  f112  f135  f136
# 711884  None  None  None  None  None  None  None  None  None  None
# 310047  None  None  None  None  None  None  None  None  None  None
# 692730  None  None  None  None  None  None  None  None  None  None
# 470325  None  None  None  None  None  None  None  None  None  None
# 757411  None  None  None  None  None  None  None  None  None  None
# 119388  None  None  None  None  None  None  None  None  None  None
# 133033  None  None  None  None  None  None  None  None  None  None
# 661222  None  None  None  None  None  None  None  None  None  None
# 343699  None  None  None  None  None  None  None  None  None  None
# 757108  None  None  None  None  None  None  None  None  None  None
#
# [10 rows x 372 columns]

# %%
data_dictionary = pd.read_csv(r"/content/drive/MyDrive/AmEx/details/data_dictionary.csv")

# %%
def impute_missing_values(df, strategy='median'):
    df_imputed = df.copy()
    for column in df_imputed.columns:
        if df_imputed[column].isnull().any():
            if df_imputed[column].dtype == 'float64':
                if strategy == 'mean':
                    df_imputed[column].fillna(df_imputed[column].mean(), inplace=True)
                elif strategy == 'median':
                    df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
    return df_imputed

# %%
# converting the column of df to respective dtypes as mentioned in the data dictionary
def convert_column_types(df, data_dictionary):
    type_map = {
        'Numerical': 'float64',
        'Categorical': 'category',
        'Key': 'category',
        'Label': 'category',
        'One hot encoded': 'category',
        '-': 'object',
    }
    for column in df.columns:
        if column in data_dictionary['masked_column'].values:
            dtype = data_dictionary.loc[data_dictionary['masked_column'] == column, 'Type'].iloc[0]
            if dtype in type_map:
                try:
                    df[column] = df[column].astype(type_map[dtype])
                except Exception as e:
                    print(f"Could not convert {column} to {type_map[dtype]}: {e}")
    return df

# %%
def print_object_columns(df):
    dtype_groups = {}
    for col in df.columns:
        dtype_str = str(df[col].dtype)
        dtype_groups.setdefault(dtype_str, []).append(col)
    for dtype, cols in dtype_groups.items():
        print(f"\nColumns with dtype '{dtype}' ({len(cols)} columns):")
        for col in cols:
            print(f"  - {col}")

# %%
# rearranging in ascending order of missing values less than 25%
sorted_columns = missing_value_count[missing_value_count < 0.40 * len(df)].sort_values(ascending=True).index.tolist()
df_25 = df[sorted_columns]

# %%
df_25 = convert_column_types(df_25, data_dictionary)
# Out:
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# Could not convert id4 to float64: could not convert string to float: '2023-11-02 22:22:00.042'
# Could not convert id5 to float64: could not convert string to float: '2023-11-02'
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])
# /tmp/ipython-input-11-4006871157.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = df[column].astype(type_map[dtype])

# %%
df_25.dtypes.value_counts()
# Out:
# float64     199
# category     48
# category     36
# object        3
# category      2
# category      1
# category      1
# category      1
# category      1
# category      1
# category      1
# category      1
# category      1
# category      1
# Name: count, dtype: int64

# %%
print_object_columns(df_25)
# Out:
# Columns with dtype 'category' (91 columns):
#   - f349
#   - id1
#   - id3
#   - y
#   - f226
#   - f227
#   - f229
#   - f230
#   - f266
#   - f265
#   - f264
#   - f263
#   - f262
#   - f261
#   - f260
#   - f259
#   - f282
#   - f281
#   - f280
#   - f279
#   - f278
#   - f277
#   - f276
#   - f275
#   - f267
#   - f268
#   - f269
#   - f270
#   - f271
#   - f304
#   - f307
#   - f306
#   - f294
#   - f293
#   - f285
#   - f297
#   - f298
#   - f299
#   - f308
#   - f309
#   - f295
#   - f296
#   - f288
#   - f287
#   - f286
#   - f292
#   - f289
#   - f290
#   - f274
#   - f273
#   - f272
#   - f291
#   - f250
#   - f305
#   - f302
#   - f303
#   - f239
#   - f240
#   - f241
#   - f242
#   - f243
#   - f244
#   - f245
#   - f246
#   - f231
#   - f232
#   - f233
#   - f234
#   - f235
#   - f228
#   - f237
#   - f238
#   - f247
#   - f248
#   - f249
#   - f284
#   - f283
#   - f258
#   - f257
#   - f256
#   - f255
#   - f254
#   - f252
#   - f236
#   - f251
#   - f300
#   - f253
#   - f301
#   - f354
#   - f52
#   - f50
#
# Columns with dtype 'float64' (160 columns):
#   - f350
#   - f335
#   - f223
#   - f225
#   - f224
#   - f333
#   - f332
#   - f334
#   - f201
#   - f203
#   - f204
#   - f199
#   - f200
#   - f202
#   - f99
#   - f94
#   - f95
#   - f113
#   - f100
#   - f102
#   - f103
#   - f97
#   - f96
#   - f98
#   - f101
#   - f77
#   - f89
#   - f75
#   - f72
#   - f91
#   - f87
#   - f65
#   - f71
#   - f86
#   - f62
#   - f90
#   - f74
#   - f61
#   - f93
#   - f63
#   - f60
#   - f67
#   - f73
#   - f59
#   - f69
#   - f76
#   - f68
#   - f109
#   - f105
#   - f38
#   - f108
#   - f106
#   - f85
#   - f128
#   - f124
#   - f147
#   - f148
#   - f125
#   - f146
#   - f123
#   - f127
#   - f149
#   - f129
#   - f126
#   - f137
#   - f132
#   - f28
#   - f157
#   - f179
#   - f152
#   - f178
#   - f177
#   - f186
#   - f185
#   - f180
#   - f182
#   - f181
#   - f171
#   - f172
#   - f174
#   - f173
#   - f184
#   - f169
#   - f170
#   - f183
#   - f163
#   - f162
#   - f161
#   - f175
#   - f167
#   - f164
#   - f166
#   - f165
#   - f155
#   - f153
#   - f168
#   - f156
#   - f159
#   - f158
#   - f160
#   - f198
#   - f359
#   - f111
#   - f214
#   - f213
#   - f215
#   - f216
#   - f138
#   - f30
#   - f150
#   - f134
#   - f107
#   - f130
#   - f365
#   - f364
#   - f366
#   - f133
#   - f362
#   - f363
#   - f361
#   - f131
#   - f346
#   - f345
#   - f344
#   - f339
#   - f340
#   - f338
#   - f343
#   - f337
#   - f342
#   - f336
#   - f341
#   - f352
#   - f353
#   - f358
#   - f351
#   - f6
#   - f151
#   - f356
#   - f355
#   - f319
#   - f322
#   - f318
#   - f316
#   - f357
#   - f324
#   - f321
#   - f317
#   - f315
#   - f314
#   - f320
#   - f323
#   - f41
#   - f47
#   - f51
#   - f44
#   - f49
#   - f46
#   - f45
#   - f313
#
# Columns with dtype 'object' (3 columns):
#   - id2
#   - id4
#   - id5

# %%
missing_cols = df_25.columns[df_25.isnull().any()]
dtype_counts = df_25[missing_cols].dtypes.value_counts()
print("Number of columns with missing values grouped by dtype in df_25:")
print(dtype_counts)
# Out:
# Number of columns with missing values grouped by dtype in df_25:
# float64     198
# category     48
# category     36
# category      2
# category      1
# category      1
# category      1
# category      1
# category      1
# Name: count, dtype: int64

# %%
df_25_imputed = impute_missing_values(df_25, strategy='median')
# Out:
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# ...
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)
# /tmp/ipython-input-10-1598317052.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_imputed[column].fillna(df_imputed[column].median(), inplace=True)

# %%
missing_cols_imputed = df_25_imputed.columns[df_25_imputed.isnull().any()]
dtype_counts_imputed = df_25_imputed[missing_cols_imputed].dtypes.value_counts()
print("Number of columns with missing values grouped by dtype in df_25:")
print(dtype_counts_imputed)
# Out:
# Number of columns with missing values grouped by dtype in df_25:
# category    48
# category    36
# category     2
# category     1
# category     1
# category     1
# category     1
# category     1
# Name: count, dtype: int64

# %%
df_25_imputed.isnull().sum().sort_values(ascending=False)[:90]
# Out:
# f55     254467
# f53     254467
# f56     254467
# f54     254467
# f50     190663
#          ...
# f282        18
# f281        18
# f248        18
# f250        18
# f237        18
# Length: 90, dtype: int64

# %%
def impute_one_hot_encoded_with_median(df, data_dictionary):
    skip_cols = {"f50", "f52", "f354"}
    one_hot_cols = data_dictionary[data_dictionary['Type'].str.lower().str.contains('one hot encoded')]['masked_column'].tolist()

    cols_to_impute = [
        col for col in one_hot_cols
        if col in df.columns and col not in skip_cols and df[col].isnull().any()
    ]

    df_imputed = df.copy()

    for col in cols_to_impute:
        # Coerce to numeric if needed
        df_imputed[col] = pd.to_numeric(df_imputed[col], errors='coerce')
        median_val = df_imputed[col].median()
        if pd.notna(median_val):
            df_imputed[col] = df_imputed[col].fillna(median_val)
        else:
            print(f"⚠️ Skipping column {col} — median is NaN (possibly all missing)")

    return df_imputed

# %%
df_imputed_all = impute_one_hot_encoded_with_median(df_25_imputed, data_dictionary)

# %%
missing_cols_imputed = df_imputed_all.columns[df_imputed_all.isnull().any()]
dtype_counts_imputed = df_imputed_all[missing_cols_imputed].dtypes.value_counts()
print("Number of columns with missing values grouped by dtype in df_25:")
print(dtype_counts_imputed)
# Out:
# Number of columns with missing values grouped by dtype in df_25:
# category    2
# category    1
# category    1
# category    1
# category    1
# category    1
# Name: count, dtype: int64

# %%
df_imputed_all['f56'].unique()
# Out:
# [NaN, 'G', 'B', 'S', 'D']
# Categories (4, object): ['B', 'D', 'G', 'S']

# %%
df_imputed_all.isnull().sum().sort_values(ascending=False)[:10]
# Out:
# f54     254467
# f56     254467
# f53     254467
# f55     254467
# f52     190663
# f50     190663
# f354    141991
# f150         0
# f30          0
# f216         0
# dtype: int64

# %%
print_feature_details(df_imputed_all.columns[df_imputed_all.isnull().any()].sort_values(ascending=False), data_dictionary)
# Out:
# ID: f56
# Description: H Code Tier
# Type: Categorical
# Missing Values: 254467
# ------------------------------------------------------------
# ID: f55
# Description: HG Vacation Club
# Type: Categorical
# Missing Values: 254467
# ------------------------------------------------------------
# ID: f54
# Description: Honors enrollees with Stay Activity within the last 12 months = A
# Type: Categorical
# Missing Values: 254467
# ------------------------------------------------------------
# ID: f53
# Description: Value assigned to member 1=lowest  5=highest
# Type: Categorical
# Missing Values: 254467
# ------------------------------------------------------------
# ID: f52
# Description: Active Part y1
# Type: Categorical
# Missing Values: 190663
# ------------------------------------------------------------
# ID: f50
# Description: Account Creation Indicator
# Type: Categorical
# Missing Values: 190663
# ------------------------------------------------------------
# ID: f354
# Description: Depicts days since launch
# Type: Categorical
# Missing Values: 141991
# ------------------------------------------------------------

# %%
import seaborn as sns

# %%
df_imputed_all = df_imputed_all.select_dtypes(include=['float64', 'int64'])

# %%
df_imputed_all.isnull().sum().sort_values(ascending=False)[:90]
# Out:
# f350    0
# f335    0
# f223    0
# f225    0
# f226    0
#        ..
# f254    0
# f252    0
# f236    0
# f251    0
# f300    0
# Length: 90, dtype: int64

# %%
# correlation plot cluster heatmap function
# def plot_correlation_heatmap(df, title='Correlation Heatmap'):
#     corr = df.corr()
#     plt.figure(figsize=(10, 8))
#     sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
#     plt.title(title)
#     plt.show()

# # correlation heatmap for the DataFrame with imputed values (df_imputed_all)
# if df_imputed_all.empty:
#     print("DataFrame is empty after imputation.")
# else:
#     print("Correlation Heatmap for DataFrame with Imputed Values:")
#     plot_correlation_heatmap(df_imputed_all, title='Correlation Heatmap of Imputed DataFrame')

# plot_correlation_heatmap(df_imputed_all, title='Correlation Heatmap of Imputed DataFrame')

# %%
event_df = pd.read_parquet("/content/drive/MyDrive/AmEx/data/add_event.parquet")

# %%
trans_df = pd.read_parquet("/content/drive/MyDrive/AmEx/data/add_trans.parquet")

# %%
offer_df = pd.read_parquet("/content/drive/MyDrive/AmEx/data/offer_metadata.parquet")

# %%
event_df.sample(10)
# Out:
#               id2        id3        id6                      id4   id7
# 11395859  2824706     699005  OffersTab  2023-10-29 19:58:29.931  None
# 4800408   2751185      87731      Tiles  2023-10-28 20:58:36.451  None
# 16121715  2605204       1398      Tiles  2023-11-02 06:09:19.338  None
# 13462489  2100473  542986322      Tiles  2023-10-26 05:40:47.331  None
# 3439162   2201965      34826      Tiles  2023-10-29 16:03:20.123  None
# 10700633  2261067      87102  OffersTab  2023-11-01 18:22:23.079  None
# 11744620  2591352      76604      Tiles  2023-11-01 17:59:42.463  None
# 18263490  2281435      62259      Tiles  2023-10-26 04:39:05.716  None
# 7752227   2651028     958700      Tiles  2023-11-01 10:54:47.438  None
# 17592846  2531650      77410  OffersTab  2023-10-29 10:06:05.462  None

# %%
for col in event_df.columns:
    print(f"{col} : {event_df[col].nunique()}")
    print_feature_details([col], data_dictionary)
# Out:
# id2 : 428195
# ID: id2
# Description: Customer ID (masked)
# Type: -
# ------------------------------------------------------------
# id3 : 923
# ID: id3
# Description: Offer ID
# Type: Categorical
# ------------------------------------------------------------
# id6 : 3
# ID: id6 - No information available in data dictionary.
# ------------------------------------------------------------
# id4 : 20794419
# ID: id4
# Description: Event timestamp
# Type: Numerical
# ------------------------------------------------------------
# id7 : 398756
# ID: id7 - No information available in data dictionary.
# ------------------------------------------------------------

# %%
# prompt: write a function which tell me all the necessary things about the dataset and which i should know

def explore_dataset(df:pd.DataFrame, df_name="DataFrame"):
    """
    Prints key information about a Pandas DataFrame.

    Args:
        df (pd.DataFrame): The DataFrame to explore.
        df_name (str): The name of the DataFrame (for printing purposes).
    """
    print(f"--- Exploring {df_name} ---")

    # Basic Info
    print(f"\nShape: {df.shape}")
    print("\nInfo:")
    df.info()

    # Descriptive Statistics
    print("\nDescriptive Statistics:")
    print(df.describe(include='all'))

    # Missing Values
    print("\nMissing Values (Count and Percentage):")
    missing_count = df.isnull().sum()
    missing_percent = (missing_count / len(df)) * 100
    missing_info = pd.DataFrame({
        'Missing Count': missing_count,
        'Missing Percentage (%)': missing_percent
    }).sort_values(by='Missing Count', ascending=False)
    print(missing_info[missing_info['Missing Count'] > 0])

    # Data Types
    print("\nData Types:")
    print(df.dtypes.value_counts())

    # Unique Values (for non-numeric columns or columns with few unique values)
    print("\nUnique Values (for select columns):")
    for col in df.columns:
        if df[col].dtype in ['object', 'category'] or df[col].nunique() < 20:
            print(f"- {col}: {df[col].nunique()} unique values")
            feature_info = data_dictionary[data_dictionary['masked_column'] == col]
            if not feature_info.empty:
                for _, row in feature_info.iterrows():
                    print(f"- Description: {row['Description']}\n- Type: {row['Type']}")
            else:
                print(f"ID: {col} - No information available in data dictionary.\n{'-'*60}")
            if df[col].nunique() <= 10: # Print value counts for columns with very few unique values
                print(df[col].value_counts(dropna=False))

    # Check for duplicate rows
    print(f"\nNumber of duplicate rows: {df.duplicated().sum()}")

    print(f"\n--- End of Exploration for {df_name} ---")

# %%
# Example usage with your dataframes:
# explore_dataset(df, "Train Data")
# explore_dataset(test_df, "Test Data")
# explore_dataset(event_df, "Add Event Data")
# explore_dataset(trans_df, "Add Trans Data")
# explore_dataset(offer_df, "Offer Metadata")
# explore_dataset(data_dictionary, "Data Dictionary")
# explore_dataset(df_25, "df_25 (Imputed up to 25% missing)")
# explore_dataset(df_imputed_all, "df_imputed_all (Final Imputed)")

# %%
print_feature_details(offer_df.columns, data_dictionary)
# Out:
# ID: id3
# Description: Offer ID
# Type: Categorical
# ------------------------------------------------------------
# ID: id9 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: f375 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: f376 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: f377 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: id10 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: id11 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: f378 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: f374 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: id8 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: id12 - No information available in data dictionary.
# ------------------------------------------------------------
# ID: id13 - No information available in data dictionary.
# ------------------------------------------------------------

# %%
offer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4164 entries, 0 to 4163
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id3     4164 non-null   int32
#  1   id9     4164 non-null   object
#  2   f375    4164 non-null   int32
#  3   f376    978 non-null    float64
#  4   f377    0 non-null      object
#  5   id10    4164 non-null   object
#  6   id11    0 non-null      object
#  7   f378    4164 non-null   object
#  8   f374    3887 non-null   object
#  9   id8     3887 non-null   object
#  10  id12    4164 non-null   object
#  11  id13    4164 non-null   object
# dtypes: float64(1), int32(2), object(9)
# memory usage: 358.0+ KB

# %%
event_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21457473 entries, 0 to 21457472
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id2     int32
#  1   id3     object
#  2   id6     object
#  3   id4     object
#  4   id7     object
# dtypes: int32(1), object(4)
# memory usage: 736.7+ MB

# %%
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6339465 entries, 0 to 6339464
# Data columns (total 9 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   id2     int32
#  1   f367    float64
#  2   f368    object
#  3   f369    object
#  4   f370    object
#  5   f371    object
#  6   f372    object
#  7   id8     object
#  8   f374    object
# dtypes: float64(1), int32(1), object(7)
# memory usage: 411.1+ MB

# %%
explore_dataset(df_25, "df_25 (Imputed up to 25% missing)")
# Out:
# --- Exploring df_25 (Imputed up to 25% missing) ---
#
# Shape: (770164, 254)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770164 entries, 0 to 770163
# Columns: 254 entries, f349 to f313
# dtypes: category(91), float64(160), object(3)
# memory usage: 1.0+ GB
#
# Descriptive Statistics:
#           f349           f350                                          id1  \
# count   770164  770164.000000                                       770164
# unique       4            NaN                                       770164
# top          4            NaN  1910568_73186_16-23_2023-11-03 23:10:57.764
# freq    301584            NaN                                            1
# mean       NaN   43888.750377                                          NaN
# std        NaN   19134.165795                                          NaN
# min        NaN      23.000000                                          NaN
# 25%        NaN   28974.000000                                          NaN
# 50%        NaN   41739.000000                                          NaN
# 75%        NaN   58921.000000                                          NaN
# max        NaN   86393.000000                                          NaN
#
#             id2     id3                      id4         id5       y  \
# count    770164  770164                   770164      770164  770164
# unique    46550     757                   763371           3       2
# top     1396352   92636  2023-11-01 16:04:43.564  2023-11-01       0
# freq        510    2446                        5      301698  733113
# mean        NaN     NaN                      NaN         NaN     NaN
# std         NaN     NaN                      NaN         NaN     NaN
# min         NaN     NaN                      NaN         NaN     NaN
# 25%         NaN     NaN                      NaN         NaN     NaN
# 50%         NaN     NaN                      NaN         NaN     NaN
# 75%         NaN     NaN                      NaN         NaN     NaN
# max         NaN     NaN                      NaN         NaN     NaN
#
#             f335           f223  ...            f41           f47  \
# count   770146.0  770146.000000  ...  586765.000000  5.795010e+05
# unique       NaN            NaN  ...            NaN           NaN
# top          NaN            NaN  ...            NaN           NaN
# freq         NaN            NaN  ...            NaN           NaN
# mean         0.0      38.521389  ...    1334.418259  4.865899e+04
# std          0.0      46.533114  ...    4114.276084  1.463993e+05
# min          0.0      -2.000000  ...   -8702.110000  0.000000e+00
# 25%          0.0       1.000000  ...     160.150000  7.700000e+02
# 50%          0.0      27.000000  ...     602.150000  7.613000e+03
# 75%          0.0      58.000000  ...    1550.900000  3.568700e+04
# max          0.0     933.000000  ...  221123.730000  4.652958e+06
#
#                   f51           f44           f49     f52     f50  \
# count   579501.000000  5.795010e+05  5.795010e+05  579501  579501
# unique            NaN           NaN           NaN       2       2
# top               NaN           NaN           NaN       N       N
# freq              NaN           NaN           NaN  353776  293172
# mean      4225.277223  5.038177e+03  1.294729e+04     NaN     NaN
# std       3693.642285  5.983452e+04  5.770378e+04     NaN     NaN
# min         30.000000  0.000000e+00  0.000000e+00     NaN     NaN
# 25%        778.000000  0.000000e+00  0.000000e+00     NaN     NaN
# 50%       3166.000000  0.000000e+00  0.000000e+00     NaN     NaN
# 75%       6962.000000  0.000000e+00  0.000000e+00     NaN     NaN
# max      15393.000000  6.239000e+06  5.206269e+06     NaN     NaN
#
#                  f46            f45           f313
# count   5.795010e+05  579501.000000  577761.000000
# unique           NaN            NaN            NaN
# top              NaN            NaN            NaN
# freq             NaN            NaN            NaN
# mean    4.253361e+04       7.190961       0.079883
# std     1.282388e+05      18.510864       0.083755
# min     0.000000e+00       0.000000       0.000000
# 25%     0.000000e+00       0.000000       0.053937
# 50%     6.277000e+03       0.000000       0.061555
# 75%     3.046500e+04       6.000000       0.083023
# max     3.156141e+06     414.000000       1.000000
#
# [11 rows x 254 columns]
#
# Missing Values (Count and Percentage):
#       Missing Count  Missing Percentage (%)
# f313         192403               24.982082
# f50          190663               24.756156
# f52          190663               24.756156
# f49          190663               24.756156
# f46          190663               24.756156
# ...             ...                     ...
# f257             18                0.002337
# f256             18                0.002337
# f255             18                0.002337
# f254             18                0.002337
# f252             18                0.002337
#
# [246 rows x 2 columns]
#
# Data Types:
# float64     160
# category     48
# category     36
# object        3
# category      2
# category      1
# category      1
# category      1
# category      1
# category      1
# Name: count, dtype: int64
#
# Unique Values (for select columns):
# - f349: 4 unique values
# - Description: context variable fetched in real time where 1 for Monday, 2 for Tuesday,…………, 7 for Sunday
# - Type: Categorical
# f349
# 4    301584
# 5    246700
# 6    221741
# 3       139
# Name: count, dtype: int64
# - id1: 770164 unique values
# - Description: Primary Key(masked)
# - Type: Key
# - id2: 46550 unique values
# - Description: Customer ID (masked)
# - Type: -
# - id3: 757 unique values
# - Description: Offer ID
# - Type: Categorical
# - id4: 763371 unique values
# - Description: Event timestamp
# - Type: Numerical
# - id5: 3 unique values
# - Description: Event Date
# - Type: Numerical
# id5
# 2023-11-01    301698
# 2023-11-02    246621
# 2023-11-03    221845
# Name: count, dtype: int64
# - y: 2 unique values
# - Description: Dependent Variable
# - Type: Label
# y
# 0    733113
# 1     37051
# Name: count, dtype: int64
# - f335: 1 unique values
# - Description: Coupon offers
# - Type: Numerical
# f335
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f226: 1 unique values
# - Description: Offer category Business
# - Type: One hot encoded
# f226
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f227: 2 unique values
# - Description: Offer category dining
# - Type: One hot encoded
# f227
# 0.0    728976
# 1.0     41170
# NaN        18
# Name: count, dtype: int64
# - f229: 1 unique values
# - Description: Offer category retail
# - Type: One hot encoded
# f229
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f230: 2 unique values
# - Description: Offer category services
# - Type: One hot encoded
# f230
# 0.0    714321
# 1.0     55825
# NaN        18
# Name: count, dtype: int64
# - f266: 1 unique values
# - Description: Offer sub category french
# - Type: One hot encoded
# f266
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f265: 2 unique values
# - Description: Offer sub category food wine
# - Type: One hot encoded
# f265
# 0.0    749052
# 1.0     21094
# NaN        18
# Name: count, dtype: int64
# - f264: 2 unique values
# - Description: Offer sub category food store
# - Type: One hot encoded
# f264
# 0.0    764927
# 1.0      5219
# NaN        18
# Name: count, dtype: int64
# - f263: 2 unique values
# - Description: Offer sub category finance
# - Type: One hot encoded
# f263
# 0.0    766715
# 1.0      3431
# NaN        18
# Name: count, dtype: int64
# - f262: 1 unique values
# - Description: Offer sub category european
# - Type: One hot encoded
# f262
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f261: 2 unique values
# - Description: Offer sub category electronics
# - Type: One hot encoded
# f261
# 0.0    763720
# 1.0      6426
# NaN        18
# Name: count, dtype: int64
# - f260: 1 unique values
# - Description: Offer sub category education
# - Type: One hot encoded
# f260
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f259: 1 unique values
# - Description: Offer sub category delis
# - Type: One hot encoded
# f259
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f282: 2 unique values
# - Description: Offer sub category mexican
# - Type: One hot encoded
# f282
# 0.0    769020
# 1.0      1126
# NaN        18
# Name: count, dtype: int64
# - f281: 1 unique values
# - Description: Offer sub category mediterranean
# - Type: One hot encoded
# f281
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f280: 2 unique values
# - Description: Offer sub category jewelry
# - Type: One hot encoded
# f280
# 0.0    738875
# 1.0     31271
# NaN        18
# Name: count, dtype: int64
# - f279: 1 unique values
# - Description: Offer sub category japanese
# - Type: One hot encoded
# f279
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f278: 2 unique values
# - Description: Offer sub category italian
# - Type: One hot encoded
# f278
# 0.0    769594
# 1.0       552
# NaN        18
# Name: count, dtype: int64
# - f277: 1 unique values
# - Description: Offer sub category indian
# - Type: One hot encoded
# f277
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f276: 2 unique values
# - Description: Offer sub category hotel resorts
# - Type: One hot encoded
# f276
# 0.0    752067
# 1.0     18079
# NaN        18
# Name: count, dtype: int64
# - f275: 2 unique values
# - Description: Offer sub category home garden
# - Type: One hot encoded
# f275
# 0.0    745741
# 1.0     24405
# NaN        18
# Name: count, dtype: int64
# - f267: 1 unique values
# - Description: Offer sub category fusion
# - Type: One hot encoded
# f267
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f268: 1 unique values
# - Description: Offer sub category german
# - Type: One hot encoded
# f268
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f269: 2 unique values
# - Description: Offer sub category gifts
# - Type: One hot encoded
# f269
# 0.0    736861
# 1.0     33285
# NaN        18
# Name: count, dtype: int64
# - f270: 1 unique values
# - Description: Offer sub category golf
# - Type: One hot encoded
# f270
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f271: 1 unique values
# - Description: Offer sub category greek
# - Type: One hot encoded
# f271
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f304: 1 unique values
# - Description: Offer sub category tour
# - Type: One hot encoded
# f304
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f307: 1 unique values
# - Description: Offer sub category utilities
# - Type: One hot encoded
# f307
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f306: 2 unique values
# - Description: Offer sub category travel agencies
# - Type: One hot encoded
# f306
# 0.0    767886
# 1.0      2260
# NaN        18
# Name: count, dtype: int64
# - f294: 1 unique values
# - Description: Offer sub category real estate
# - Type: One hot encoded
# f294
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f293: 2 unique values
# - Description: Offer sub category professional
# - Type: One hot encoded
# f293
# 0.0    766453
# 1.0      3693
# NaN        18
# Name: count, dtype: int64
# - f285: 2 unique values
# - Description: Offer sub category other
# - Type: One hot encoded
# f285
# 1.0    453682
# 0.0    316464
# NaN        18
# Name: count, dtype: int64
# - f297: 2 unique values
# - Description: Offer sub category seafood
# - Type: One hot encoded
# f297
# 0.0    767931
# 1.0      2215
# NaN        18
# Name: count, dtype: int64
# - f298: 1 unique values
# - Description: Offer sub category services
# - Type: One hot encoded
# f298
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f299: 2 unique values
# - Description: Offer sub category shipping services
# - Type: One hot encoded
# f299
# 0.0    768466
# 1.0      1680
# NaN        18
# Name: count, dtype: int64
# - f308: 1 unique values
# - Description: Offer sub category vegetarian
# - Type: One hot encoded
# f308
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f309: 1 unique values
# - Description: Offer sub category wholesale
# - Type: One hot encoded
# f309
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f295: 1 unique values
# - Description: Offer sub category residential care
# - Type: One hot encoded
# f295
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f296: 2 unique values
# - Description: Offer sub category restaurant
# - Type: One hot encoded
# f296
# 0.0    768698
# 1.0      1448
# NaN        18
# Name: count, dtype: int64
# - f288: 2 unique values
# - Description: Offer sub category other shopping
# - Type: One hot encoded
# f288
# 0.0    739491
# 1.0     30655
# NaN        18
# Name: count, dtype: int64
# - f287: 1 unique values
# - Description: Offer sub category other services
# - Type: One hot encoded
# f287
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f286: 1 unique values
# - Description: Offer sub category other cuisine
# - Type: One hot encoded
# f286
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f292: 2 unique values
# - Description: Offer sub category printing
# - Type: One hot encoded
# f292
# 0.0    768174
# 1.0      1972
# NaN        18
# Name: count, dtype: int64
# - f289: 2 unique values
# - Description: Offer sub category parking
# - Type: One hot encoded
# f289
# 0.0    768490
# 1.0      1656
# NaN        18
# Name: count, dtype: int64
# - f290: 1 unique values
# - Description: Offer sub category parks zoos
# - Type: One hot encoded
# f290
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f274: 2 unique values
# - Description: Offer sub category home furnishing
# - Type: One hot encoded
# f274
# 0.0    747462
# 1.0     22684
# NaN        18
# Name: count, dtype: int64
# - f273: 2 unique values
# - Description: Offer sub category hobbies
# - Type: One hot encoded
# f273
# 0.0    763509
# 1.0      6637
# NaN        18
# Name: count, dtype: int64
# - f272: 2 unique values
# - Description: Offer sub category health care
# - Type: One hot encoded
# f272
# 0.0    769046
# 1.0      1100
# NaN        18
# Name: count, dtype: int64
# - f291: 1 unique values
# - Description: Offer sub category personal care
# - Type: One hot encoded
# f291
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f250: 2 unique values
# - Description: Offer sub category casual
# - Type: One hot encoded
# f250
# 0.0    769542
# 1.0       604
# NaN        18
# Name: count, dtype: int64
# - f305: 2 unique values
# - Description: Offer sub category transportation
# - Type: One hot encoded
# f305
# 0.0    769842
# 1.0       304
# NaN        18
# Name: count, dtype: int64
# - f302: 2 unique values
# - Description: Offer sub category steakhouse
# - Type: One hot encoded
# f302
# 0.0    769459
# 1.0       687
# NaN        18
# Name: count, dtype: int64
# - f303: 1 unique values
# - Description: Offer sub category thai
# - Type: One hot encoded
# f303
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f239: 2 unique values
# - Description: Offer sub category asian
# - Type: One hot encoded
# f239
# 0.0    769647
# 1.0       499
# NaN        18
# Name: count, dtype: int64
# - f240: 1 unique values
# - Description: Offer sub category australian
# - Type: One hot encoded
# f240
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f241: 2 unique values
# - Description: Offer sub category auto fuel
# - Type: One hot encoded
# f241
# 0.0    766523
# 1.0      3623
# NaN        18
# Name: count, dtype: int64
# - f242: 2 unique values
# - Description: Offer sub category auto rental
# - Type: One hot encoded
# f242
# 0.0    766061
# 1.0      4085
# NaN        18
# Name: count, dtype: int64
# - f243: 1 unique values
# - Description: Offer sub category auto sales
# - Type: One hot encoded
# f243
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f244: 2 unique values
# - Description: Offer sub category auto services
# - Type: One hot encoded
# f244
# 0.0    766036
# 1.0      4110
# NaN        18
# Name: count, dtype: int64
# - f245: 1 unique values
# - Description: Offer sub category automotive
# - Type: One hot encoded
# f245
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f246: 1 unique values
# - Description: Offer sub category bar night
# - Type: One hot encoded
# f246
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f231: 2 unique values
# - Description: Offer category shopping
# - Type: One hot encoded
# f231
# 1.0    628523
# 0.0    141623
# NaN        18
# Name: count, dtype: int64
# - f232: 2 unique values
# - Description: Offer category travel
# - Type: One hot encoded
# f232
# 0.0    732263
# 1.0     37883
# NaN        18
# Name: count, dtype: int64
# - f233: 2 unique values
# - Description: Offer sub category Activities and leisure
# - Type: One hot encoded
# f233
# 0.0    766514
# 1.0      3632
# NaN        18
# Name: count, dtype: int64
# - f234: 2 unique values
# - Description: Offer sub category advertising
# - Type: One hot encoded
# f234
# 0.0    767637
# 1.0      2509
# NaN        18
# Name: count, dtype: int64
# - f235: 2 unique values
# - Description: Offer sub category american
# - Type: One hot encoded
# f235
# 0.0    765971
# 1.0      4175
# NaN        18
# Name: count, dtype: int64
# - f228: 2 unique values
# - Description: Offer category entertainment
# - Type: One hot encoded
# f228
# 0.0    744818
# 1.0     25328
# NaN        18
# Name: count, dtype: int64
# - f237: 2 unique values
# - Description: Offer sub category apparel
# - Type: One hot encoded
# f237
# 0.0    726000
# 1.0     44146
# NaN        18
# Name: count, dtype: int64
# - f238: 1 unique values
# - Description: Offer sub category argentinean
# - Type: One hot encoded
# f238
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f247: 2 unique values
# - Description: Offer sub category books music
# - Type: One hot encoded
# f247
# 0.0    770079
# 1.0        67
# NaN        18
# Name: count, dtype: int64
# - f248: 1 unique values
# - Description: Offer sub category british
# - Type: One hot encoded
# f248
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f249: 1 unique values
# - Description: Offer sub category carry out
# - Type: One hot encoded
# f249
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f333: 2 unique values
# - Description: Redemption mode is in-store
# - Type: Numerical
# f333
# 0.0    622293
# 1.0    147853
# NaN        18
# Name: count, dtype: int64
# - f332: 2 unique values
# - Description: Redemption mode is Online
# - Type: Numerical
# f332
# 1.0    622293
# 0.0    147853
# NaN        18
# Name: count, dtype: int64
# - f334: 1 unique values
# - Description: Redemption mode is phone
# - Type: Numerical
# f334
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f284: 2 unique values
# - Description: Offer sub category office supplies
# - Type: One hot encoded
# f284
# 0.0    768095
# 1.0      2051
# NaN        18
# Name: count, dtype: int64
# - f283: 2 unique values
# - Description: Offer sub category office products
# - Type: One hot encoded
# f283
# 0.0    768095
# 1.0      2051
# NaN        18
# Name: count, dtype: int64
# - f258: 1 unique values
# - Description: Offer sub category cuisin
# - Type: One hot encoded
# f258
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f257: 2 unique values
# - Description: Offer sub category cruises
# - Type: One hot encoded
# f257
# 0.0    769316
# 1.0       830
# NaN        18
# Name: count, dtype: int64
# - f256: 2 unique values
# - Description: Offer sub category constructions
# - Type: One hot encoded
# f256
# 0.0    768042
# 1.0      2104
# NaN        18
# Name: count, dtype: int64
# - f255: 2 unique values
# - Description: Offer sub category computer services
# - Type: One hot encoded
# f255
# 0.0    766876
# 1.0      3270
# NaN        18
# Name: count, dtype: int64
# - f254: 2 unique values
# - Description: Offer sub category communications
# - Type: One hot encoded
# f254
# 0.0    768530
# 1.0      1616
# NaN        18
# Name: count, dtype: int64
# - f252: 2 unique values
# - Description: Offer sub category clothing
# - Type: One hot encoded
# f252
# 0.0    682168
# 1.0     87978
# NaN        18
# Name: count, dtype: int64
# - f236: 1 unique values
# - Description: Offer sub category animal services
# - Type: One hot encoded
# f236
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f251: 2 unique values
# - Description: Offer sub category chinese
# - Type: One hot encoded
# f251
# 0.0    770067
# 1.0        79
# NaN        18
# Name: count, dtype: int64
# - f300: 1 unique values
# - Description: Offer sub category spanish
# - Type: One hot encoded
# f300
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f253: 2 unique values
# - Description: Offer sub category coffee desserts
# - Type: One hot encoded
# f253
# 0.0    768577
# 1.0      1569
# NaN        18
# Name: count, dtype: int64
# - f301: 1 unique values
# - Description: Offer sub category sports recreation
# - Type: One hot encoded
# f301
# 0.0    770146
# NaN        18
# Name: count, dtype: int64
# - f102: 1 unique values
# - Description: If offer type Insurance then impressions in last 180 days
# - Type: Numerical
# f102
# 0.0    762461
# NaN      7703
# Name: count, dtype: int64
# - f71: 3 unique values
# - Description: Total time spent in |ESTATEMENT| page in the last 180 days
# - Type: Numerical
# f71
# 0.0        761901
# NaN          8185
# 27352.0        77
# 156.0           1
# Name: count, dtype: int64
# - f62: 1 unique values
# - Description: Total time spent in |ESTATEMENT| page in the last 30 days
# - Type: Numerical
# f62
# 0.0    761979
# NaN      8185
# Name: count, dtype: int64
# - f128: 1 unique values
# - Description: Number of clicks for category business expenses in last 60 days
# - Type: Numerical
# f128
# 0.0    733350
# NaN     36814
# Name: count, dtype: int64
# - f129: 1 unique values
# - Description: Number of clicks for category retail in last 60 days
# - Type: Numerical
# f129
# 0.0    733350
# NaN     36814
# Name: count, dtype: int64
# - f359: 2 unique values
# - Description: Financial hardship trigger scores for USCS customers
# - Type: Numerical
# f359
# 0.0    725345
# NaN     42989
# 1.0      1830
# Name: count, dtype: int64
# - f354: 2 unique values
# - Description: Depicts days since launch
# - Type: Categorical
# f354
# Rest       537421
# NaN        141991
# Phase_1     90752
# Name: count, dtype: int64
# - f52: 2 unique values
# - Description: Active Part y1
# - Type: Categorical
# f52
# N      353776
# Y      225725
# NaN    190663
# Name: count, dtype: int64
# - f50: 2 unique values
# - Description: Account Creation Indicator
# - Type: Categorical
# f50
# N      293172
# Y      286329
# NaN    190663
# Name: count, dtype: int64
#
# Number of duplicate rows: 0
#
# --- End of Exploration for df_25 (Imputed up to 25% missing) ---

# %%
df_25['f224'].nunique()
# Out:
# 180
